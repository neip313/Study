# %% [markdown]
# # 14장 형 변환 함수

# %% [markdown]
# ## 목차
# - 14.1. TO_CHAR( ) : 문자형으로 변환
# - 14.2. TO_DATE( ) : 날짜형으로 변환
# - 14.3. TO_NUMBER( ) : 수치형으로 변환
# - 14.4. CHR( ) : 수치를 ASCII(아스키)문자로 변환
# - 14.5. ASCII( ) : ASCII(아스키) 문자를 수치로 변환

# %% [markdown]
# ## 14.1 TO_CHAR() : 문자형으로 변환
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 14.2 TO_DATE() : 날짜형을 변환
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 14.3 TO_NUMBER() : 수치형으로 변환
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 14.4 CHR() : 수치를 ASCII 문자로 변환
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 14.5 ASCII() : ASCII 문자를 수치로 변환
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
