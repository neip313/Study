# %% [markdown]
# # 16장 행정보 관련 함수

# %% [markdown]
# ## 목차
# - 16.1. LEAD( ) : 다음 행의 항목 값 취득
# - 16.2. LAG( ) : 이전 행의 항목 값 취득
# - 16.3. XMLAgg, XMLElement : 그룹에 대한 행 정보를 열 정보로 변환

# %% [markdown]
# ## 16.1 LEAD() : 다음 행의 항목 값 취득
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 16.2 LAG() : 이전 행의 항목 값 취득
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 16.3 XMLAgg,  XMLEIement : 그룹에 대한 행 정보를 열 정보로 변환
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
