# %% [markdown]
# # 13장 비교함수

# %% [markdown]
# ## 목차
# - 13.1. DECODE( ) : 비교 결과에 따른 값 설정
# - 13.2. NVL( ) : NULL(값이 할당 안 됨)인 경우 값 설정
# - 13.3. LEAST( ) : 지정 값 중 최소값 취득
# - 13.4. GREATEST( ) : 지정 값 중 최대값 취득
# - 13.5. WIDTH_BUCKET( ) : 지정 값의 구간 위치 취득

# %% [markdown]
# ## 13.1 DECODE() : 비교 결과에 따른 값 설정
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 13.2 NVL() : NULL(값이 할당 안 됨)인 경우 값 설정
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 13.3  LEAST() : 지정 값 중 최소값 취득
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 13.4 GREATEST() : 지정 값 중 최대값 취득
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 13.5 WIDTH_BUCKET() : 지정 값의 구간 위치 취득
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
