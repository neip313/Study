# %% [markdown]
# # 15장 그룹함수

# %% [markdown]
# ## 목차
# - 15.1. MAX( ) : 그룹 항목의 최대값 취득
# - 15.2. MIN( ) : 그룹 항목의 최소값 취득
# - 15.3. SUM( ) : 그룹 항목의 합계 취득
# - 15.4. AVG( ) : 그룹 항목의 평균 취득
# - 15.5. COUNT( ) : 그룹 항목의 개수 취득
# - 15.6. ROLLUP( ) : 그룹 항목의 소계 및 합계 취득
# - 15.7. ROW_NUMBER( ) : 중복 없는 순차 순번 부여
# - 15.8. RANK( ) : 동일 값 중복 수넌 후 순위만큼 이동한 순번 부여
# - 15.9. DENSE_RANK( ) : 동일 값 중복 순번 후 순차 순번 부여
# - 15.10. RANK( ) WITHIN : RANK() 순번 처리 후 지정 값의 위치 취득
# - 15.11 FIRST_VALUE() : RANK() 순번 처리 후 지정 값의 위치 취득

# %% [markdown]
# ## 15.1 MAX() : 그룹 항목의 최대값 취득
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 15.2 MIN() : 그룹 항목의 최소값 취득
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 15.3 SUM() : 그룹 항목의 합계 취득
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 15.4 AVG() : 그룹 항목의 평균 취득
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 15.5 COUNT() : 그룹 항목의 개수 취득
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 15.6 ROLLUP() : 그룹 항목의 소계 및 합계 취득
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 15.7 ROW_NUMBER() : 중복 없는 순차 순번 부여
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 15.8 RANK() : 동일 값 중복 순번 후 순위만큼 이동한 순번 부여
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 15.9 DENCE_RANK() : 동일 값 중복 순번 후 순차 순번 부여
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 15.10 RANK() WITHIN : RANK() 순번 처리 후 값의 위치 취득
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 15. 11 FIRST_VALUE() : RANK() 순번 처리 후 지정 값의 위치 취득
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
