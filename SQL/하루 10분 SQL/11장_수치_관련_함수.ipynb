# %% [markdown]
# # 11장 수치 관련 함수
# - 11.1. ABS( ) : 절대값 취득
# - 11.2. MOD( ) : 나누기 후 나머지 값 취득
# - 11.3. SQRT( ) : 제곱근 취득
# - 11.4. CEIL( ) : 올림 값 취득
# - 11.5. FLOOR( ) : 내림 값 취득
# - 11.6. ROUND( ) : 반올림 값 취득
# - 11.7. TRUNC( ) : 버림 값 취득
# - 11.8. POWER( ) : 승수 값 취득

# %% [markdown]
# ## 11.1 ABS()
# - KEYWORD : 절대값 취득
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 11.2 MOD()
# - KEYWORD : 나누기 후 나머지 값 취득
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 11.3 SQRT()
# - KEYWORD : 제곱근 취득
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 11.4 CEIL()
# - KEYWORD : 올림 값 취득
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 11.5 FLOOR()
# - KEYWORD : 내림 값 취득
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 11.6 ROUND()
# - KEYWORD : 반올림 값 취득
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 11.7 TRUNC()
# - KEYWORD : 버림 값 취득
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 11.8 POWER()
# - KEYWORD : 승수 값 취득
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
