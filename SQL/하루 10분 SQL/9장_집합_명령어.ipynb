# %% [markdown]
# # 9장 집합명령어
# 1. UNION : 중복 없는 합집합을 만든다.
# 2. UNION ALL : 중복을 허용하는 합집합을 만든다.
# 3. INTERSECT : 교집합을 만든다.
# 4. MINUS : 차집합을 만든다.

# %% [markdown]
# ## 9.1 UNION
# - KEYWORD : 중복 없는 합집합
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 9.2 UNION ALL
# - KEYWORD : 중복된 합집합
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 9.3 INTERSECT
# - KEYWORD : 교집합
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 9.4 MINUS
# - KEYWORD : 차집합
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
