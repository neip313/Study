# %% [markdown]
# ## 4. 빅데이터 탐색

# %% [markdown]
# ### 1) 빅데이터 탐색 개요
# ---
#
# - 빅데이터 처리 및 탐색 영역은 적재된 데이터를 가공하고 이해하는 단계
#  - 데이터를 이해하는 과정에서는 데이터들의 패턴, 관계, 트렌드 등을 찾게 되는 것을 탐색적 분석이라 함
#    - 탐색적 분석을 하기위해서는 2v(Volume[크기], Varity[다양성])의 비정형 데이터를 정교한 후처리 작업(필터링, 클린징, 분리, 통합 등)으로 정형화한 저장소가 필요, 이 역할을 하는 곳이 빅데이터 웨어하우스
# - 빅데이터 처리/탐색의 최종 결과물은 빅데이터 웨어하우스 기반의 마트이며, 빅데이터 분석/응용에 활용

# %% [markdown]
# ### 2)빅데이터 탐색에 활용되는 기술
# ---
#
# **하이브**
#
# - 하둡 초창기에는 적재된 데이터를 탐색/분석하기 위한 도구로 맵리듀스를 주로 이용
#  - 맵리듀스는 복잡도가 높은 프로그래밍 기법이 필요
#    - 업무 분석가 및 관리자들에게 빅데이터 접근하는 것을 어렵게 만듬
# - 맵리듀스의 복잡도를 해결하기 위해 페이스북에서 SQL과 매우 유사한 방식으로 하둡 데이터에 접근성을 높임

# %% [markdown]
# ![1.PNG](data:image/png;base64,...)

# %% [markdown]
# <center> 하이브의 기본 요소 </center>

# %% [markdown]
# **스파크**
#
# - 하이브는 복잡한 맵리듀스를 하이브 QL로 래핑해 접근성을 높일 수 있었지만 맵리듀수 코어를 그대로 사용함으로써 만족스러운 성능을 내지 못함
#  - 반복적인 대화형 연산 작업에서는 하이브가 적합하지 않음
# - 하이브의 단점을 보완하고 하이브와 호환이 가능
# - 하이브에 비해 속도가 현저하게 증가(약 40배)

# %% [markdown]
# ![2.PNG](data:image/png;base64,...)

# %% [markdown]
# <center> 스파크의 기본 요소 </center>

# %% [markdown]
# **우지**
#
# - 하이브, 스파크, 피그 등을 이해해 빅데이터의 처리, 탐색, 분석하는 과정은 복합한 선후행 관계를 맺고 반복적으로 진행
#  - 대규모 빅데이터 시스템에서는 수집 및 적재된 수백 개 이상의 데이터셋을 대상으로 다양한 후처리 잡(JOB)이 데이터 간의 의존성을 지켜가며 복잡하게 실행<br>
# ```JOB: 1개의 맵리듀스```
# - 복잡한 데이터 파이프라인 작업을 위해 방향성 있는 비순환 그래프로 잡의 시작, 처리, 분기, 종료점 등의 액션 등을 정의하는 워크플로의 역할을 함

# %% [markdown]
# ![3.PNG](data:image/png;base64,...)

# %% [markdown]
# <center> 우지의 기본 요소 </center>

# %% [markdown]
# **휴**
#
# - 빅데이터 탐색/분석은 장기간의 반복 작업이면서 그 과정에 있어 많은 도구들이 필요
#  - 주로 하둡을 기반으로 하이브, 우지, 피그, 스파크 등이 해당되며 일반 분석가 또는 담당자들이 각 서버에 직접 접속해 사용하기 어려움
# - 빅데이터 기술이 발전하면서 이러한 기술의 복잡도를 낮추고 접근성과 편의성을 높인 소프트웨어

# %% [markdown]
# ![4.PNG](data:image/png;base64,...)

# %% [markdown]
# <center> 휴의 기본 요소 </center>

# %% [markdown]
# ## 5. 빅데이터 분석

# %% [markdown]
# ### 1) 빅데이터 분석 개요
# ---
#
# - 빅데이터 분석은 탐색과 분석을 반복하며 의미 있는 데이터를 추출해 문제를 검증하고 주요 의사결정을 내리는 과정
# - 목적에 따라 분석의 유형은 5가지로 정의
#  - 기술 분석: 분석 초기 데이터의 특징을 파악하기 위해 선택, 집계, 요약 등 양적 기술 분석을 수행
#  - 탐색 분석: 업무 도메인 지식을 기반으로 대규모 데이터셋의 상관관계나 연관성을 파악
#  - 추론 분석: 전통적인 통계분석 기법으로 문제에 대한 가설을 세우고 샘플링을 통해 가설을 검증
#  - 인과 분석: 문제 해결을 위한 원인과 결과 변수를 도출하고 변수의 영향도를 분석
#  - 예측 분석: 대규모 과거 데이터를 학습해 예측 모형을 만들고, 최근의 데이터로 미래를 예측
# - 분석 기술을 통해 빅데이터의 가치는 "Raw 데이터 → 정보 → 통찰력 → 가치" 순으로 변화
#  - 통찰력을 갖게 되는 단계에서 빅데이터의 활용 효익이 만들어지기 시작
#    - 주로 상품 및 서비스 개발, 마케팅 및 캠페인 지원, 리스크 관리 등의 영역에서 주요 의사결정을 내릴 때 사용

# %% [markdown]
# ### 2) 빅데이터 분석에 활용 기술
# ---
#
# **임팔라**
#
# - 하이브가 맵리듀스를 대체하는 SQL on Hadoop의 도구로 자리 잡음
#  - 생태계(현업)에서는 하이브의 배치성 분석에 만족하지 못하고, 빅데이터의 분석을 인메모리 기반의 실시간 온라인 분석으로까지 확대되길 원함<br>
# ```하이브는 맵리듀스 프레임워크를 사용, 임팔라는 실시간 응답을 위한 고유의 분산 질의 엔진을 사용```
# - 드레멜 논문에 영향을 받아 개발됨

# %% [markdown]
# ![5.PNG](data:image/png;base64,...)

# %% [markdown]
# <center> 임팔라의 기본 요소 </center>

# %% [markdown]
# **제플린**
#
# - 대용량의 데이터를 효과적으로 탐색 및 분석하기 위해서는 대용량 데이터셋을 빠르게 파악하고 이해하기 위한 분석 및 시간 툴이 필요
#  - R은 하둡의 분산 파일을 직적 참조할 수 없고 병렬처리가 어려워 하둡의 대규모 데이터를 분석하는데 어려움이 발생
#    - 이러한 문제를 해결하기 위해 스파크를 기반으로 하는 제플린이 탄생

# %% [markdown]
# ![6.PNG](data:image/png;base64,...)

# %% [markdown]
# <center> 제플린의 기본 요소 </center>

# %% [markdown]
# **머하웃**
#
# - 하둡 생태계에서 머신러닝 기법을 이용해 데이터 마이닝을 수행하는 툴
# - 하둡에서 분산 머신러닝을 하기 위해 검색엔진 루씬의 서브 프로젝트로 시작
#  - 하둡의 분산 아키텍처를 바탕으로 텍스트마이닝, 군집, 분류 등 같은 머신러닝 기반 기술이 내재 됨

# %% [markdown]
# ![7.PNG](data:image/png;base64,...)

# %% [markdown]
# <center> 머하웃의 기본 요소 </cneter>

# %% [markdown]
# **스쿱**
#
# - RDBMS와 HDFS 사이에서 데이터를 편리하게 임포트하거나 익스포트해주는 소프트웨어

# %% [markdown]
# ![8.PNG](data:image/png;base64,...)

# %% [markdown]
# <center> 스콥의 기본 요소 </center>
